# %% [markdown]
# # Criando tabelas

# %%
import pandas as pd

# %% [markdown]
# ## Criando a partir de listas

# %%
data = [1,2,3,4]

df = pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# ## Criando a partir de lista de listas

# %%
data = [
        [1,2],
        [3,4],
        [5,6]
    ]

df = pd.DataFrame(data)
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %% [markdown]
# ## A partir de dicionário de listas

# %%
data = {"Nome": ['Alexandre','Caio','Jonas','Priscilla'],
        "Sobrenome": ['Clemente', 'Alexandre', 'de Sá','Souza']}

df = pd.DataFrame(data)
df
# Out:
#         Nome  Sobrenome
# 0  Alexandre   Clemente
# 1       Caio  Alexandre
# 2      Jonas      de Sá
# 3  Priscilla      Souza

# %% [markdown]
# ## Criando com índice

# %%
data = {"Nome": ['Alexandre','Caio','Jonas','Priscilla'],
        "Sobrenome": ['Clemente', 'Alexandre', 'de Sá','Souza']}

df = pd.DataFrame(data, index=['pessoa1','pessoa2','pessoa3','pessoa4'])
df
# Out:
#               Nome  Sobrenome
# pessoa1  Alexandre   Clemente
# pessoa2       Caio  Alexandre
# pessoa3      Jonas      de Sá
# pessoa4  Priscilla      Souza

# %% [markdown]
# ## Criando a partir de uma lista de dicionários

# %%
data = [
        {'Nome': 'Alexandre', 'Sobrenome': 'Pinheiro'},
        {'Nome': 'Caio', 'Sobrenome': 'Alexandre'},
        {'Nome': 'Jonas', 'Sobrenome': 'de Sá'}
       ]

df = pd.DataFrame(data)
list(df.columns)
# Out:
# ['Nome', 'Sobrenome']

# %%
list(df.index)
# Out:
# [0, 1, 2]

# %% [markdown]
# ### Informação de linhas e colunas da matriz

# %%
df.shape
# Out:
# (3, 2)
